# %% [markdown]
# #### Get Filtered dataframe of All students and Year 2022:

# %%
import pandas as pd

# Load the Excel file
file_path = './cleaned_all_ap_participation.xlsx'  # Replace with your file path
df = pd.read_excel(file_path)

df['Student Group'].unique()
# Out:
# array(['Multi', 'HispanicLatino', 'StudentDisability', 'Male',
#        'EnglishLearner', 'Asian', 'Nat', 'HighNeeds', 'LowIncome',
#        'Female', 'Black', 'AmerInd', 'White'], dtype=object)

# %%
# All Students
df_all_students_2022 = df[(df['Student Group'] == 'All Students') & (df['Year'] == 2022)]
df_all_students_2021 = df[(df['Student Group'] == 'All Students') & (df['Year'] == 2021)]

# Afr. Amer./Black
df_afr_amer_black_2022 = df[(df['Student Group'] == 'Afr. Amer./Black') & (df['Year'] == 2022)]
df_afr_amer_black_2021 = df[(df['Student Group'] == 'Afr. Amer./Black') & (df['Year'] == 2021)]

# White
df_white_2022 = df[(df['Student Group'] == 'White') & (df['Year'] == 2022)]
df_white_2021 = df[(df['Student Group'] == 'White') & (df['Year'] == 2021)]

# Nat. Haw. or Pacif. Isl.
df_nat_haw_pac_isl_2022 = df[(df['Student Group'] == 'Nat. Haw. or Pacif. Isl.') & (df['Year'] == 2022)]
df_nat_haw_pac_isl_2021 = df[(df['Student Group'] == 'Nat. Haw. or Pacif. Isl.') & (df['Year'] == 2021)]

# Asian
df_asian_2022 = df[(df['Student Group'] == 'Asian') & (df['Year'] == 2022)]
df_asian_2021 = df[(df['Student Group'] == 'Asian') & (df['Year'] == 2021)]

# Hispanic/Latino
df_hispanic_latino_2022 = df[(df['Student Group'] == 'Hispanic/Latino') & (df['Year'] == 2022)]
df_hispanic_latino_2021 = df[(df['Student Group'] == 'Hispanic/Latino') & (df['Year'] == 2021)]

# Amer. Ind. or Alaska Nat.
df_amer_ind_alaska_nat_2022 = df[(df['Student Group'] == 'Amer. Ind. or Alaska Nat.') & (df['Year'] == 2022)]
df_amer_ind_alaska_nat_2021 = df[(df['Student Group'] == 'Amer. Ind. or Alaska Nat.') & (df['Year'] == 2021)]

# Female
df_female_2022 = df[(df['Student Group'] == 'Female') & (df['Year'] == 2022)]
df_female_2021 = df[(df['Student Group'] == 'Female') & (df['Year'] == 2021)]

# Male
df_male_2022 = df[(df['Student Group'] == 'Male') & (df['Year'] == 2022)]
df_male_2021 = df[(df['Student Group'] == 'Male') & (df['Year'] == 2021)]

# High needs
df_high_needs_2022 = df[(df['Student Group'] == 'High needs') & (df['Year'] == 2022)]
df_high_needs_2021 = df[(df['Student Group'] == 'High needs') & (df['Year'] == 2021)]

# Low Income
df_low_income_2022 = df[(df['Student Group'] == 'Low Income') & (df['Year'] == 2022)]
df_low_income_2021 = df[(df['Student Group'] == 'Low Income') & (df['Year'] == 2021)]

# Students w/disabilities
df_students_disabilities_2022 = df[(df['Student Group'] == 'Students w/disabilities') & (df['Year'] == 2022)]
df_students_disabilities_2021 = df[(df['Student Group'] == 'Students w/disabilities') & (df['Year'] == 2021)]

# English Learner
df_english_learner_2022 = df[(df['Student Group'] == 'English Learner') & (df['Year'] == 2022)]
df_english_learner_2021 = df[(df['Student Group'] == 'English Learner') & (df['Year'] == 2021)]

# %% [markdown]
# #### Get each district's Average Score

# %%
# Calculate the mean score for every district
def get_mean_score(filtered_df):
    district_avg_scores = {}
    for index, row in filtered_df.iterrows():
        score_sum = 0
        count = 0
        
        for i in range(1, 6):
            if not pd.isnull(row[f'Test={i}']):
                score_sum += i * row[f'Test={i}']
                count += row[f'Test={i}']
                
        # If there are available scores, get the mean score of the district
        if count != 0:
            district_avg_scores[row['District Name']] = score_sum / count
            
    return district_avg_scores

# %%
#### Create a new dataframe with the calculated average scores
# Afr. Amer./Black
result_df_afr_amer_black_2022 = pd.DataFrame(list(get_mean_score(df_afr_amer_black_2022).items()), columns=['District Name', 'Average Score'])
result_df_afr_amer_black_2021 = pd.DataFrame(list(get_mean_score(df_afr_amer_black_2021).items()), columns=['District Name', 'Average Score'])

# White
result_df_white_2022 = pd.DataFrame(list(get_mean_score(df_white_2022).items()), columns=['District Name', 'Average Score'])
result_df_white_2021 = pd.DataFrame(list(get_mean_score(df_white_2021).items()), columns=['District Name', 'Average Score'])

# Nat. Haw. or Pacif. Isl.
result_df_nat_haw_pac_isl_2022 = pd.DataFrame(list(get_mean_score(df_nat_haw_pac_isl_2022).items()), columns=['District Name', 'Average Score'])
result_df_nat_haw_pac_isl_2021 = pd.DataFrame(list(get_mean_score(df_nat_haw_pac_isl_2021).items()), columns=['District Name', 'Average Score'])

# Asian
result_df_asian_2022 = pd.DataFrame(list(get_mean_score(df_asian_2022).items()), columns=['District Name', 'Average Score'])
result_df_asian_2021 = pd.DataFrame(list(get_mean_score(df_asian_2021).items()), columns=['District Name', 'Average Score'])

# Hispanic/Latino
result_df_hispanic_latino_2022 = pd.DataFrame(list(get_mean_score(df_hispanic_latino_2022).items()), columns=['District Name', 'Average Score'])
result_df_hispanic_latino_2021 = pd.DataFrame(list(get_mean_score(df_hispanic_latino_2021).items()), columns=['District Name', 'Average Score'])

# Amer. Ind. or Alaska Nat.
result_df_amer_ind_alaska_nat_2022 = pd.DataFrame(list(get_mean_score(df_amer_ind_alaska_nat_2022).items()), columns=['District Name', 'Average Score'])
result_df_amer_ind_alaska_nat_2021 = pd.DataFrame(list(get_mean_score(df_amer_ind_alaska_nat_2021).items()), columns=['District Name', 'Average Score'])

# Female
result_df_female_2022 = pd.DataFrame(list(get_mean_score(df_female_2022).items()), columns=['District Name', 'Average Score'])
result_df_female_2021 = pd.DataFrame(list(get_mean_score(df_female_2021).items()), columns=['District Name', 'Average Score'])

# Male
result_df_male_2022 = pd.DataFrame(list(get_mean_score(df_male_2022).items()), columns=['District Name', 'Average Score'])
result_df_male_2021 = pd.DataFrame(list(get_mean_score(df_male_2021).items()), columns=['District Name', 'Average Score'])

# High needs
result_df_high_needs_2022 = pd.DataFrame(list(get_mean_score(df_high_needs_2022).items()), columns=['District Name', 'Average Score'])
result_df_high_needs_2021 = pd.DataFrame(list(get_mean_score(df_high_needs_2021).items()), columns=['District Name', 'Average Score'])

# Low Income
result_df_low_income_2022 = pd.DataFrame(list(get_mean_score(df_low_income_2022).items()), columns=['District Name', 'Average Score'])
result_df_low_income_2021 = pd.DataFrame(list(get_mean_score(df_low_income_2021).items()), columns=['District Name', 'Average Score'])

# Students w/disabilities
result_df_students_disabilities_2022 = pd.DataFrame(list(get_mean_score(df_students_disabilities_2022).items()), columns=['District Name', 'Average Score'])
result_df_students_disabilities_2021 = pd.DataFrame(list(get_mean_score(df_students_disabilities_2021).items()), columns=['District Name', 'Average Score'])

# English Learner
result_df_english_learner_2022 = pd.DataFrame(list(get_mean_score(df_english_learner_2022).items()), columns=['District Name', 'Average Score'])
result_df_english_learner_2021 = pd.DataFrame(list(get_mean_score(df_english_learner_2021).items()), columns=['District Name', 'Average Score'])

# %% [markdown]
# #### Plot Heat Maps of AP CS Average Scores in Masachusetts in Year 2021 and 2022

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import pandas as pd

def get_heatmap_avg_score(df, title):
    # If df is empty, return a warning
    if df.empty:
        print(f"Warning: Empty For {title}")
        return 
    
    # Load your Shapefile with the polygons of the year 2000
    gdf = gpd.read_file('./TOWNSSURVEY_POLYM_GENCOAST.shp') ## gdf is Geographical Data File

    # Merge the GeoDataFrame and the pandas DataFrame on the "TOWN" column
    merged = gdf.merge(df, left_on='TOWN', right_on='District Name', how='left')

    # Define a color map for color mapping
    cmap = LinearSegmentedColormap.from_list('mycmap', ['lightyellow', 'darkred'])

    # Create a plot with custom styling
    fig, ax = plt.subplots(1, 1, figsize=(10, 5))

    # Specify the color for missing data (grey in this case)
    missing_color = 'lightgray'

    # Get max and min average score
    max_score = 5 #df['Average Score'].max()
    min_score = 1 #df['Average Score'].min()
    
    # Plot the GeoDataFrame with color mapping and specify missing data color
    merged.plot(
        column='Average Score',
        cmap=cmap,
        missing_kwds={'color': missing_color},
        vmin=min_score,
        vmax=max_score,
        ax=ax,
        legend=True
    )

    # Remove x and y axis ticks
    ax.set_xticks([])
    ax.set_yticks([])

    # Customize the plot (e.g., add a title)
    ax.set_title(title)

    # Show the plot
    plt.show()

# %%
### Generate Heatmaps
# Afr. Amer./Black
get_heatmap_avg_score(result_df_afr_amer_black_2022, "Average Total AP CS Exams of Afr. Amer./Black Students in Massachusetts in 2022")
get_heatmap_avg_score(result_df_afr_amer_black_2021, "Average Total AP CS Exams of Afr. Amer./Black Students in Massachusetts in 2021")

# White
get_heatmap_avg_score(result_df_white_2022, "Average Total AP CS Exams of White Students in Massachusetts in 2022")
get_heatmap_avg_score(result_df_white_2021, "Average Total AP CS Exams of White Students in Massachusetts in 2021")

# Nat. Haw. or Pacif. Isl.
get_heatmap_avg_score(result_df_nat_haw_pac_isl_2022, "Average AP Total CS Exams of Nat. Haw. or Pacif. Isl. Students in Massachusetts in 2022")
get_heatmap_avg_score(result_df_nat_haw_pac_isl_2021, "Average AP Total CS Exams of Nat. Haw. or Pacif. Isl. Students in Massachusetts in 2021")

# Asian
get_heatmap_avg_score(result_df_asian_2022, "Average Total AP CS Exams of Asian Students in Massachusetts in 2022")
get_heatmap_avg_score(result_df_asian_2021, "Average Total AP CS Exams of Asian Students in Massachusetts in 2021")

# Hispanic/Latino
get_heatmap_avg_score(result_df_hispanic_latino_2022, "Average Total AP CS Exams of Hispanic/Latino Students in Massachusetts in 2022")
get_heatmap_avg_score(result_df_hispanic_latino_2021, "Average Total AP CS Exams of Hispanic/Latino Students in Massachusetts in 2021")

# Amer. Ind. or Alaska Nat.
get_heatmap_avg_score(result_df_amer_ind_alaska_nat_2022, "Average Total AP CS Exams of Amer. Ind. or Alaska Nat. Students in Massachusetts in 2022")
get_heatmap_avg_score(result_df_amer_ind_alaska_nat_2021, "Average Total AP CS Exams of Amer. Ind. or Alaska Nat. Students in Massachusetts in 2021")

# Female
get_heatmap_avg_score(result_df_female_2022, "Average Total AP CS Exams of Female Students in Massachusetts in 2022")
get_heatmap_avg_score(result_df_female_2021, "Average Total AP CS Exams of Female Students in Massachusetts in 2021")

# Male
get_heatmap_avg_score(result_df_male_2022, "Average Total AP CS Exams of Male Students in Massachusetts in 2022")
get_heatmap_avg_score(result_df_male_2021, "Average Total AP CS Exams of Male Students in Massachusetts in 2021")

# High needs
get_heatmap_avg_score(result_df_high_needs_2022, "Average Total AP CS Exams of High Needs Students in Massachusetts in 2022")
get_heatmap_avg_score(result_df_high_needs_2021, "Average Total AP CS Exams of High Needs Students in Massachusetts in 2021")

# Low Income
get_heatmap_avg_score(result_df_low_income_2022, "Average AP Total CS Exams of Low Income Students in Massachusetts in 2022")
get_heatmap_avg_score(result_df_low_income_2021, "Average AP Total CS Exams of Low Income Students in Massachusetts in 2021")

# Students w/disabilities
get_heatmap_avg_score(result_df_students_disabilities_2022, "Average AP Total CS Exams of Students w/Disabilities in Massachusetts in 2022")
get_heatmap_avg_score(result_df_students_disabilities_2021, "Average AP Total CS Exams of Students w/Disabilities in Massachusetts in 2021")

# English Learner
get_heatmap_avg_score(result_df_english_learner_2022, "Average Total AP CS Exams of English Learners in Massachusetts in 2022")
get_heatmap_avg_score(result_df_english_learner_2021, "Average Total AP CS Exams of English Learners in Massachusetts in 2021")

# %% [markdown]
# #### Plot Histograms for Different Student Groups in Year 2021 and 2022

# %%
import numpy as np
import pandas as pd

# Load the Excel file
file_path = './cleaned_all_ap_participation.xlsx'  # Replace with your file path
df = pd.read_excel(file_path)

# Group the DataFrame by 'Year' and 'Student Group' and sum the columns
df_grouped = df.groupby(['Year', 'Student Group']).sum().reset_index()

# Calculate the weighted average score for each group and year
score_columns = ['Test=1', 'Test=2', 'Test=3', 'Test=4', 'Test=5']
numerator = np.sum(df_grouped[score_columns] * np.array([1, 2, 3, 4, 5]), axis=1)
denominator = np.sum(df_grouped[score_columns], axis=1)
df_grouped['Weighted Avg Score'] = np.where(denominator > 0, numerator / denominator, np.nan)

# Iterate through each year and create a separate plot
years = df_grouped['Year'].unique()

for year in years:
    year_data = df_grouped[df_grouped['Year'] == year]
    student_groups = year_data['Student Group']
    average_scores = year_data['Weighted Avg Score']

    # Create a bar plot for the current year
    plt.figure(figsize=(8, 4))
    plt.bar(student_groups, average_scores)
    plt.title(f'Average Tests by Student Groups for Year {year}')
    plt.xlabel('Student Groups')
    plt.ylabel('Average Scores')
    plt.xticks(rotation=45, ha='right')

    plt.show()
